# %% [markdown]
# implement the Item-Based Collaborative Memory Network (ICMN) recommendation system:

# %%
import pandas as pd
df = pd.read_csv("/content/ratings.dat",sep="::", header=None, names=["UserID", "MovieID", "Rating", "TimeStamp"])
# Out:
# <ipython-input-11-230f9cb2a084>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv("/content/ratings.dat",sep="::", header=None, names=["UserID", "MovieID", "Rating", "TimeStamp"])

# %%
df.head()
# Out:
#    UserID  MovieID  Rating  TimeStamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
# 2       1      914       3  978301968
# 3       1     3408       4  978300275
# 4       1     2355       5  978824291

# %%
import numpy as np

class ICMN:
    def __init__(self, num_items, embedding_dim, alpha, beta):
        self.num_items = num_items
        self.embedding_dim = embedding_dim
        self.alpha = alpha
        self.beta = beta
        self.item_embeddings = np.random.randn(num_items, embedding_dim)
        self.item_similarities = np.zeros((num_items, num_items))

    def compute_item_similarities(self, interactions):
      # Compute co-occurrence matrix
      cooccurrence_matrix = np.zeros((self.num_items, self.num_items))
      for user_interactions in interactions.values():
          for i in range(len(user_interactions)):
              for j in range(i + 1, len(user_interactions)):
                  item_i = user_interactions[i]
                  item_j = user_interactions[j]
                  cooccurrence_matrix[item_i, item_j] += 1
                  cooccurrence_matrix[item_j, item_i] += 1
      # Compute item similarities using cosine similarity
      norms = np.linalg.norm(cooccurrence_matrix, axis=1)

      for i in range(self.num_items):
          for j in range(i + 1, self.num_items):
              similarity = np.dot(cooccurrence_matrix[i], cooccurrence_matrix[j]) / (norms[i] * norms[j])
              self.item_similarities[i, j] = similarity
              self.item_similarities[j, i] = similarity


    def update_item_embeddings(self, interactions):
        for user_interactions in interactions.values():
            for i in range(len(user_interactions) - 1):
                item_i = user_interactions[i]
                item_j = user_interactions[i + 1]
                error = self.item_embeddings[item_i] - self.alpha * self.item_embeddings[item_j]
                self.item_embeddings[item_i] -= self.beta * error

    def fit(self, interactions, num_epochs):
        for epoch in range(num_epochs):
            print(f"Epoch {epoch + 1}/{num_epochs}")
            self.compute_item_similarities(interactions)
            self.update_item_embeddings(interactions)

    def recommend_items(self, user_interactions, top_k):
        user_embeddings = np.mean(self.item_embeddings[user_interactions], axis=0)
        item_scores = np.dot(user_embeddings, self.item_embeddings.T)
        top_items = np.argsort(item_scores)[::-1][:top_k]
        return top_items

    def compute_loss(self, interactions):
      total_loss = 0
      num_predictions = 0

      for user_id, user_interactions in interactions.items():
          for i in range(len(user_interactions) - 1):
              item_i = user_interactions[i]
              item_j = user_interactions[i + 1]
              predicted_error = self.item_embeddings[item_i] - self.alpha * self.item_embeddings[item_j]
              actual_error = self.item_embeddings[item_i] - self.item_embeddings[item_j]
              rating = interactions[user_id][i + 1]  # Fetch the rating from the interactions dictionary
              squared_error = np.sum((predicted_error * rating - actual_error) ** 2)
              total_loss += squared_error
              num_predictions += 1

      mse_loss = total_loss / num_predictions
      rmse_loss = np.sqrt(mse_loss)
      return rmse_loss



def load_ratings(filename):
    interactions = {}

    with open(filename, 'r') as file:
        for line in file:
            parts = line.strip().split("::")
            if len(parts) != 4:
                continue

            user_id, item_id, rating, timestamp = parts
            user_id = int(user_id)
            item_id = int(item_id)

            if user_id not in interactions:
                interactions[user_id] = []

            interactions[user_id].append(item_id)

    return interactions


def load_movies(filename):
    movies = {}

    with open(filename, 'r', encoding='latin1') as file:
        for line in file:
            parts = line.strip().split("::")
            if len(parts) != 3:
                continue

            item_id, title, _ = parts
            item_id = int(item_id)

            movies[item_id] = title

    return movies


filename = '/content/ratings.dat'
interactions = load_ratings(filename)


movies_filename = '/content/movies.dat'
movies = load_movies(movies_filename)

num_items = max(max(items) for items in interactions.values()) + 1
embedding_dim = 20
alpha = 0.5
beta = 0.01

icmn = ICMN(num_items, embedding_dim, alpha, beta)
icmn.fit(interactions, num_epochs=20)

loss = icmn.compute_loss(interactions)
print("Root mean squared error:", loss)
# Out:
# Epoch 1/20
# <ipython-input-16-0ab49f621cda>:28: RuntimeWarning: invalid value encountered in double_scalars
#   similarity = np.dot(cooccurrence_matrix[i], cooccurrence_matrix[j]) / (norms[i] * norms[j])
# Epoch 2/20
# Epoch 3/20
# Epoch 4/20
# Epoch 5/20
# Epoch 6/20
# Epoch 7/20
# Epoch 8/20
# Epoch 9/20
# Epoch 10/20
# Epoch 11/20
# Epoch 12/20
# Epoch 13/20
# Epoch 14/20
# Epoch 15/20
# Epoch 16/20
# Epoch 17/20
# Epoch 18/20
# Epoch 19/20
# Epoch 20/20
# Root mean squared error: 204.8413555483708

# %%
# Get movie name
user_id = 1
user_interactions = interactions[user_id]
top_k = 5  # Number of rec movies
recommended_items = icmn.recommend_items(user_interactions, top_k)

print("Recommended Movies:")
for item_id in recommended_items:
    movie_name = movies.get(item_id, "Unknown")
    print(f"- {movie_name}")
# Out:
# Recommended Movies:
# - Associate, The (L'Associe)(1982)
# - Dangerous Game (1993)
# - Unknown
# - Other Voices, Other Rooms (1997)
# - Hungarian Fairy Tale, A (1987)

# %%
user_id = 1
user_interactions = interactions[user_id]
top_k = 3
recommended_items = icmn.recommend_items(user_interactions, top_k)
print("Recommended items:", recommended_items)
# Out:
# Recommended items: [1001  439 1540]

# %%
top_k = 3
# For all users
for user_id, user_interactions in interactions.items():
    recommended_items = icmn.recommend_items(user_interactions, top_k)
    recommended_movie_names = [movies.get(item_id, "Unknown") for item_id in recommended_items]
    print(f"Recommended items for user {user_id}: {recommended_movie_names}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Recommended items for user 1041: ['Tickle in the Heart, A (1996)', 'Unknown', 'Anguish (Angustia) (1986)']
# Recommended items for user 1042: ['Unknown', 'Caught Up (1998)', 'Night Tide (1961)']
# Recommended items for user 1043: ['Nô (1998)', 'Salut cousin! (1996)', 'Tess of the Storm Country (1922)']
# Recommended items for user 1044: ['Legend of Lobo, The (1962)', 'Silence of the Palace, The (Saimt el Qusur) (1994)', 'Buddy Boy (1999)']
# Recommended items for user 1045: ['Desert Winds (1995)', 'Nô (1998)', 'Let it Come Down: The Life of Paul Bowles (1998)']
# Recommended items for user 1046: ['Quartier Mozart (1992)', 'Nô (1998)', 'Open Season (1996)']
# Recommended items for user 1047: ['Boys, Les (1997)', 'Choices (1981)', 'Frank and Ollie (1995)']
# Recommended items for user 1048: ['Five Wives, Three Secretaries and Me (1998)', 'Gendernauts (1999)', 'Tess of the Storm Country (1922)']
# Recommended items for user 1049: ['Naturally Native (1998)', 'Unknown', 'Scream of Stone (Schrei aus Stein) (1991)']
# Recommended items for user 1050: ['Unknown', 'Ride (1998)', 'Legend of Lobo, The (1962)']
# Recommended items for user 1051: ['Und keiner weint mir nach (1996)', 'Hungarian Fairy Tale, A (1987)', 'Beloved/Friend (Amigo/Amado) (1999)']
# Recommended items for user 1052: ['Madagascar Skin (1995)', "I Don't Want to Talk About It (De eso no se habla) (1993)", 'They Bite (1996)']
# Recommended items for user 1053: ['Unknown', "One Man's Hero (1999)", 'Honigmond (1996)']
# Recommended items for user 1054: ['Und keiner weint mir nach (1996)', 'Waltzes from Vienna (1933)', 'War Stories (1995)']
# Recommended items for user 1055: ['Unknown', 'Crows and Sparrows (1949)', 'Proprietor, The (1996)']
# Recommended items for user 1056: ['Unknown', 'Century (1993)', 'Black Tights (Les Collants Noirs) (1960)']
# Recommended items for user 1057: ['Symphonie pastorale, La (1946)', 'British Intelligence (1940)', 'Penitentiary (1979)']
# Recommended items for user 1058: ['Silence of the Palace, The (Saimt el Qusur) (1994)', 'Tess of the Storm Country (1922)', 'Unknown']
# Recommended items for user 1059: ['Harvest (1998)', 'Unknown', 'Prince of Central Park, The (1999)']
# Recommended items for user 1060: ['Leopard Son, The (1996)', 'Unknown', 'Black Tights (Les Collants Noirs) (1960)']
# Recommended items for user 1061: ['Locusts, The (1997)', 'Ring, The (1927)', 'My Best Girl (1927)']
# Recommended items for user 1062: ['Legend of Lobo, The (1962)', 'Tess of the Storm Country (1922)', 'Five Wives, Three Secretaries and Me (1998)']
# Recommended items for user 1063: ["Lover's Knot (1996)", 'Unknown', 'Mouth to Mouth (Boca a boca) (1995)']
# Recommended items for user 1064: ['Prince of Central Park, The (1999)', 'Let it Come Down: The Life of Paul Bowles (1998)', 'Harvest (1998)']
# Recommended items for user 1065: ['Lay of the Land, The (1997)', 'Vermont Is For Lovers (1992)', 'Unknown']
# Recommended items for user 1066: ['Tess of the Storm Country (1922)', 'Mass Transit (1998)', 'Big Bang Theory, The (1994)']
# Recommended items for user 1067: ['Unknown', 'Open Season (1996)', 'Choices (1981)']
# Recommended items for user 1068: ['Autumn Heart (1999)', 'Gendernauts (1999)', 'Parallel Sons (1995)']
# Recommended items for user 1069: ['Mouth to Mouth (Boca a boca) (1995)', 'Unforgotten: Twenty-Five Years After Willowbrook (1996)', 'Autumn Heart (1999)']
# Recommended items for user 1070: ['Gendernauts (1999)', 'Unknown', 'Bird of Prey (1996)']
# Recommended items for user 1071: ['Beyond Bedlam (1993)', 'Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) (1991)', 'Hi-Yo Silver (1940)']
# Recommended items for user 1072: ['Five Wives, Three Secretaries and Me (1998)', 'Tess of the Storm Country (1922)', 'Legend of Lobo, The (1962)']
# Recommended items for user 1073: ['Tess of the Storm Country (1922)', 'Anguish (Angustia) (1986)', 'Ill Gotten Gains (1997)']
# Recommended items for user 1074: ['Let it Come Down: The Life of Paul Bowles (1998)', 'Tess of the Storm Country (1922)', 'Autumn Heart (1999)']
# Recommended items for user 1075: ['Outside Ozona (1998)', 'Unknown', 'Mascara (1999)']
# Recommended items for user 1076: ['Sadness of Sex, The (1995)', 'Easy Virtue (1927)', 'Downhill (1927)']
# Recommended items for user 1077: ['Und keiner weint mir nach (1996)', 'Salut cousin! (1996)', 'Hungarian Fairy Tale, A (1987)']
# Recommended items for user 1078: ['Happiness Is in the Field (1995)', 'Babymother (1998)', 'Foolish (1999)']
# Recommended items for user 1079: ['Madagascar Skin (1995)', 'Unknown', 'Ride (1998)']
# Recommended items for user 1080: ['Tess of the Storm Country (1922)', 'Waltzes from Vienna (1933)', 'Nô (1998)']
# Recommended items for user 1081: ['Somebody is Waiting (1996)', 'Unknown', 'Unknown']
# Recommended items for user 1082: ['Prince of Central Park, The (1999)', 'Und keiner weint mir nach (1996)', 'Phoenix (1998)']
# Recommended items for user 1083: ['Choices (1981)', 'Unknown', 'Sonic Outlaws (1995)']
# Recommended items for user 1084: ['Und keiner weint mir nach (1996)', 'Prince of Central Park, The (1999)', 'Gendernauts (1999)']
# Recommended items for user 1085: ['Harvest (1998)', 'Unknown', 'Unknown']
# Recommended items for user 1086: ['Tess of the Storm Country (1922)', 'Nô (1998)', 'Anguish (Angustia) (1986)']
# Recommended items for user 1087: ['Legend of Lobo, The (1962)', 'Tess of the Storm Country (1922)', 'Night Tide (1961)']
# Recommended items for user 1088: ['Sadness of Sex, The (1995)', 'Unknown', 'Unknown']
# Recommended items for user 1089: ['Sonic Outlaws (1995)', 'Harvest (1998)', 'Black Tights (Les Collants Noirs) (1960)']
# Recommended items for user 1090: ['Tess of the Storm Country (1922)', 'Ratchet (1996)', 'Legend of Lobo, The (1962)']
# Recommended items for user 1091: ['Unknown', "I Don't Want to Talk About It (De eso no se habla) (1993)", 'Let it Come Down: The Life of Paul Bowles (1998)']
# Recommended items for user 1092: ['Harvest (1998)', 'I Woke Up Early the Day I Died (1998)', 'Unknown']
# Recommended items for user 1093: ['Homage (1995)', 'Uninvited Guest, An (2000)', 'Unknown']
# Recommended items for user 1094: ['Homage (1995)', 'Squeeze (1996)', 'Buddy Boy (1999)']
# Recommended items for user 1095: ['Born to Win (1971)', 'Ratchet (1996)', 'Unknown']
# Recommended items for user 1096: ['Unknown', 'I Woke Up Early the Day I Died (1998)', 'Here Comes Cookie (1935)']
# Recommended items for user 1097: ['Let it Come Down: The Life of Paul Bowles (1998)', 'Tess of the Storm Country (1922)', 'Madagascar Skin (1995)']
# Recommended items for user 1098: ['Madagascar Skin (1995)', 'Choices (1981)', 'Ring, The (1927)']
# Recommended items for user 1099: ['Tess of the Storm Country (1922)', 'Gendernauts (1999)', 'Legend of Lobo, The (1962)']
# Recommended items for user 1100: ['Every Other Weekend (1990)', 'Und keiner weint mir nach (1996)', 'Prince of Central Park, The (1999)']
# Recommended items for user 1101: ['Unknown', 'Unforgotten: Twenty-Five Years After Willowbrook (1996)', 'Guy (1996)']
# Recommended items for user 1102: ['Und keiner weint mir nach (1996)', 'Unknown', 'Tough and Deadly (1995)']
# Recommended items for user 1103: ['Tess of the Storm Country (1922)', 'Napoleon and Samantha (1972)', 'Hoogste tijd (1995)']
# Recommended items for user 1104: ['Legend of Lobo, The (1962)', 'Tess of the Storm Country (1922)', 'Unknown']
# Recommended items for user 1105: ['Tess of the Storm Country (1922)', 'Gendernauts (1999)', 'Let it Come Down: The Life of Paul Bowles (1998)']
# Recommended items for user 1106: ['Boys, Les (1997)', 'Unknown', 'Prerokbe Ognja (1995)']
# Recommended items for user 1107: ['Black Tights (Les Collants Noirs) (1960)', 'They Bite (1996)', 'Harvest (1998)']
# Recommended items for user 1108: ['Tess of the Storm Country (1922)', 'Nô (1998)', 'Somebody is Waiting (1996)']
# Recommended items for user 1109: ['Dream Man (1995)', 'Tess of the Storm Country (1922)', 'Gendernauts (1999)']
# Recommended items for user 1110: ['Anguish (Angustia) (1986)', 'Legend of Lobo, The (1962)', 'Unknown']
# Recommended items for user 1111: ['Open Season (1996)', 'Loves of Carmen, The (1948)', 'Tickle in the Heart, A (1996)']
# Recommended items for user 1112: ['Train Ride to Hollywood (1978)', 'Somebody is Waiting (1996)', 'Homage (1995)']
# Recommended items for user 1113: ['Tess of the Storm Country (1922)', 'Prince of Central Park, The (1999)', 'Choices (1981)']
# Recommended items for user 1114: ['Champagne (1928)', 'East Palace West Palace (Dong gong xi gong) (1997)', 'Inside (1996)']
# Recommended items for user 1115: ['Prince of Central Park, The (1999)', 'Unknown', 'Legend of Lobo, The (1962)']
# Recommended items for user 1116: ['Quartier Mozart (1992)', 'Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) (1991)', 'Somewhere in the City (1997)']
# Recommended items for user 1117: ['Hungarian Fairy Tale, A (1987)', 'Tess of the Storm Country (1922)', 'Salut cousin! (1996)']
# Recommended items for user 1118: ['Garcu, Le (1995)', 'Santitos (1997)', 'Unknown']
# Recommended items for user 1119: ['Tess of the Storm Country (1922)', 'Desert Winds (1995)', 'Nô (1998)']
# Recommended items for user 1120: ['Und keiner weint mir nach (1996)', 'Unknown', 'Unknown']
# Recommended items for user 1121: ['Legend of Lobo, The (1962)', 'Unknown', 'Third World Cop (1999)']
# Recommended items for user 1122: ['Tess of the Storm Country (1922)', 'Prince of Central Park, The (1999)', 'Let it Come Down: The Life of Paul Bowles (1998)']
# Recommended items for user 1123: ['Unknown', 'Prince of Central Park, The (1999)', 'Every Other Weekend (1990)']
# Recommended items for user 1124: ['Nô (1998)', 'Legend of Lobo, The (1962)', 'Number Seventeen (1932)']
# Recommended items for user 1125: ['Gendernauts (1999)', 'Unknown', 'Ill Gotten Gains (1997)']
# Recommended items for user 1126: ['Und keiner weint mir nach (1996)', 'Tough and Deadly (1995)', 'Unknown']
# Recommended items for user 1127: ['Unknown', 'Unknown', 'Unknown']
# Recommended items for user 1128: ['Let it Come Down: The Life of Paul Bowles (1998)', 'Tess of the Storm Country (1922)', 'Hungarian Fairy Tale, A (1987)']
# Recommended items for user 1129: ['Nô (1998)', 'Quartier Mozart (1992)', 'I Woke Up Early the Day I Died (1998)']
# Recommended items for user 1130: ['Tess of the Storm Country (1922)', 'Nô (1998)', 'Und keiner weint mir nach (1996)']
# Recommended items for user 1131: ['Number Seventeen (1932)', 'Unknown', 'Unknown']
# Recommended items for user 1132: ["Associate, The (L'Associe)(1982)", 'Hungarian Fairy Tale, A (1987)', 'Salut cousin! (1996)']
# Recommended items for user 1133: ['Und keiner weint mir nach (1996)', 'Waltzes from Vienna (1933)', 'Guy (1996)']
# Recommended items for user 1134: ['Quartier Mozart (1992)', 'Unknown', 'Unknown']
# Recommended items for user 1135: ['Sexual Life of the Belgians, The (1994)', "Lover's Knot (1996)", 'Unknown']
# Recommended items for user 1136: ['Unknown', 'Unknown', 'Unknown']
# Recommended items for user 1137: ['Harvest (1998)', 'Proprietor, The (1996)', 'Homage (1995)']
# Recommended items for user 1138: ['Five Wives, Three Secretaries and Me (1998)', 'Anguish (Angustia) (1986)', 'Legend of Lobo, The (1962)']
# Recommended items for user 1139: ['Unknown', 'Roula (1995)', 'Unknown']
# Recommended items for user 1140: ['Waltzes from Vienna (1933)', 'Black Tights (Les Collants Noirs) (1960)', 'Nô (1998)']
# Recommended items for user 1141: ['Unknown', 'Salut cousin! (1996)', 'Little Indian, Big City (Un indien dans la ville) (1994)']
# Recommended items for user 1142: ['Unknown', 'Legend of Lobo, The (1962)', 'Phoenix (1998)']
# Recommended items for user 1143: ['Unknown', 'Hillbillys in a Haunted House (1967)', 'Other Voices, Other Rooms (1997)']
# Recommended items for user 1144: ["Associate, The (L'Associe)(1982)", 'Open Season (1996)', "Boricua's Bond (2000)"]
# Recommended items for user 1145: ['Eden (1997)', 'Bloody Child, The (1996)', 'Harlem River Drive (1996)']
# Recommended items for user 1146: ['Unknown', "Heaven's Burning (1997)", 'Vermin (1998)']
# Recommended items for user 1147: ['Ratchet (1996)', 'Leopard Son, The (1996)', 'Sweet Nothing (1995)']
# Recommended items for user 1148: ['Prince of Central Park, The (1999)', 'Master Ninja I (1984)', 'Unknown']
# Recommended items for user 1149: ['Tess of the Storm Country (1922)', 'Unknown', 'Unknown']
# Recommended items for user 1150: ['Homage (1995)', 'Coming Apart (1969)', 'Leopard Son, The (1996)']
# Recommended items for user 1151: ['Unknown', 'Harvest (1998)', 'Legend of Lobo, The (1962)']
# Recommended items for user 1152: ['Unknown', 'Salut cousin! (1996)', 'Unknown']
# Recommended items for user 1153: ['Five Wives, Three Secretaries and Me (1998)', 'Shadow of Angels (Schatten der Engel) (1976)', 'Anguish (Angustia) (1986)']
# Recommended items for user 1154: ['Scream of Stone (Schrei aus Stein) (1991)', 'Show, The (1995)', 'Madagascar Skin (1995)']
# Recommended items for user 1155: ['Tess of the Storm Country (1922)', 'Prince of Central Park, The (1999)', 'Und keiner weint mir nach (1996)']
# Recommended items for user 1156: ['Anguish (Angustia) (1986)', 'Unknown', 'Unknown']
# Recommended items for user 1157: ['Leopard Son, The (1996)', 'Ratchet (1996)', 'Woman in Question, The (1950)']
# Recommended items for user 1158: ['Vermont Is For Lovers (1992)', 'Unknown', 'Never Met Picasso (1996)']
# Recommended items for user 1159: ['Unknown', 'Silence of the Palace, The (Saimt el Qusur) (1994)', "Lover's Knot (1996)"]
# Recommended items for user 1160: ['Five Wives, Three Secretaries and Me (1998)', 'Unknown', 'Anguish (Angustia) (1986)']
# Recommended items for user 1161: ['Unknown', 'Caught Up (1998)', 'Five Wives, Three Secretaries and Me (1998)']
# Recommended items for user 1162: ['Let it Come Down: The Life of Paul Bowles (1998)', 'Unknown', 'Children Are Watching us, The (Bambini ci guardano, I) (1942)']
# Recommended items for user 1163: ['Tess of the Storm Country (1922)', 'Unknown', "One Man's Hero (1999)"]
# Recommended items for user 1164: ['Open Season (1996)', 'Unknown', 'Night Tide (1961)']
# Recommended items for user 1165: ['Unknown', 'Legend of Lobo, The (1962)', 'Prince of Central Park, The (1999)']
# Recommended items for user 1166: ['Tess of the Storm Country (1922)', 'Nô (1998)', 'Unknown']
# Recommended items for user 1167: ['Unknown', 'Other Voices, Other Rooms (1997)', 'Und keiner weint mir nach (1996)']
# Recommended items for user 1168: ['Anguish (Angustia) (1986)', 'Tess of the Storm Country (1922)', 'Ill Gotten Gains (1997)']
# Recommended items for user 1169: ['Tess of the Storm Country (1922)', 'Prince of Central Park, The (1999)', 'Jails, Hospitals & Hip-Hop (2000)']
# Recommended items for user 1170: ['Unknown', 'Clubland (1998)', 'Man of Her Dreams (1996)']
# Recommended items for user 1171: ['Und keiner weint mir nach (1996)', 'Unknown', 'Let it Come Down: The Life of Paul Bowles (1998)']
# Recommended items for user 1172: ['Law, The (Le Legge) (1958)', 'Unknown', 'Tough and Deadly (1995)']
# Recommended items for user 1173: ['Homage (1995)', 'Happiness Is in the Field (1995)', 'Proprietor, The (1996)']
# Recommended items for user 1174: ['Parallel Sons (1995)', 'Unknown', 'Guy (1996)']
# Recommended items for user 1175: ['Unknown', 'Tess of the Storm Country (1922)', 'Unknown']
# Recommended items for user 1176: ['Choices (1981)', 'Prince of Central Park, The (1999)', 'Phoenix (1998)']
# Recommended items for user 1177: ['Unknown', 'Nô (1998)', 'Harvest (1998)']
# Recommended items for user 1178: ['Penitentiary (1979)', 'Unknown', 'Guy (1996)']
# Recommended items for user 1179: ['Prince of Central Park, The (1999)', 'Unknown', 'Quartier Mozart (1992)']
# Recommended items for user 1180: ['Ring, The (1927)', 'Happiness Is in the Field (1995)', 'Tess of the Storm Country (1922)']
# Recommended items for user 1181: ['Und keiner weint mir nach (1996)', 'Ride (1998)', 'Number Seventeen (1932)']
# Recommended items for user 1182: ['Open Season (1996)', 'Run of the Country, The (1995)', 'Phoenix (1998)']
# Recommended items for user 1183: ['Ratchet (1996)', 'Unknown', 'Quartier Mozart (1992)']
# Recommended items for user 1184: ['Tess of the Storm Country (1922)', 'Vermont Is For Lovers (1992)', 'Open Season (1996)']
# Recommended items for user 1185: ['Gendernauts (1999)', 'Ratchet (1996)', 'Unknown']
# Recommended items for user 1186: ['Garcu, Le (1995)', 'Unknown', 'Bird of Prey (1996)']
# Recommended items for user 1187: ['Hungarian Fairy Tale, A (1987)', 'Sexual Life of the Belgians, The (1994)', 'Vermin (1998)']
# Recommended items for user 1188: ['Tess of the Storm Country (1922)', 'Night Tide (1961)', 'Choices (1981)']
# Recommended items for user 1189: ['Ring, The (1927)', 'Waltzes from Vienna (1933)', 'Unknown']
# Recommended items for user 1190: ['Tough and Deadly (1995)', 'Und keiner weint mir nach (1996)', 'Dream Man (1995)']
# Recommended items for user 1191: ['Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) (1991)', 'Bells, The (1926)', 'Fall Time (1995)']
# Recommended items for user 1192: ['Tough and Deadly (1995)', 'Love in Bloom (1935)', 'Unknown']
# Recommended items for user 1193: ['Tess of the Storm Country (1922)', 'Anguish (Angustia) (1986)', 'Honigmond (1996)']
# Recommended items for user 1194: ['Unforgotten: Twenty-Five Years After Willowbrook (1996)', 'Hippie Revolution, The (1996)', 'Invitation, The (Zaproszenie) (1986)']
# Recommended items for user 1195: ['Night Tide (1961)', 'Every Other Weekend (1990)', 'Foolish (1999)']
# Recommended items for user 1196: ['Tess of the Storm Country (1922)', 'Five Wives, Three Secretaries and Me (1998)', 'Unknown']
# Recommended items for user 1197: ['Number Seventeen (1932)', 'Unknown', 'Unknown']
# Recommended items for user 1198: ['Let it Come Down: The Life of Paul Bowles (1998)', 'Unknown', 'Kill, Baby... Kill! (Operazione Paura) (1966)']
# Recommended items for user 1199: ['Prince of Central Park, The (1999)', 'Tess of the Storm Country (1922)', 'Unknown']
# Recommended items for user 1200: ['Salut cousin! (1996)', 'Prince of Central Park, The (1999)', 'Unknown']
# Recommended items for user 1201: ['Unknown', 'Night Tide (1961)', 'Anguish (Angustia) (1986)']
# Recommended items for user 1202: ['Quartier Mozart (1992)', 'Number Seventeen (1932)', 'Nô (1998)']
# Recommended items for user 1203: ["Mat' i syn (1997)", 'Unknown', 'Unknown']
# Recommended items for user 1204: ['Tess of the Storm Country (1922)', 'Five Wives, Three Secretaries and Me (1998)', 'Prince of Central Park, The (1999)']
# Recommended items for user 1205: ['Anguish (Angustia) (1986)', 'Inside (1996)', 'Dream Man (1995)']
# Recommended items for user 1206: ['Napoleon and Samantha (1972)', 'Unknown', 'Buddy Boy (1999)']
# Recommended items for user 1207: ['Nô (1998)', 'Unknown', 'Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) (1991)']
# Recommended items for user 1208: ['Babymother (1998)', 'Unknown', 'Man of Her Dreams (1996)']
# Recommended items for user 1209: ['Prince of Central Park, The (1999)', 'Let it Come Down: The Life of Paul Bowles (1998)', 'Tess of the Storm Country (1922)']
# Recommended items for user 1210: ['Unknown', 'Tickle in the Heart, A (1996)', 'Unknown']
# Recommended items for user 1211: ['Homage (1995)', 'Spanish Fly (1998)', 'Mouth to Mouth (Boca a boca) (1995)']
# Recommended items for user 1212: ['British Intelligence (1940)', 'Rude (1995)', 'Easy Virtue (1927)']
# Recommended items for user 1213: ['Und keiner weint mir nach (1996)', 'Nô (1998)', 'Autumn Heart (1999)']
# Recommended items for user 1214: ['Anguish (Angustia) (1986)', 'Loves of Carmen, The (1948)', 'Not Love, Just Frenzy (Más que amor, frenesí) (1996)']
# Recommended items for user 1215: ['Unknown', 'Unknown', 'Choices (1981)']
# Recommended items for user 1216: ['Unknown', 'Other Voices, Other Rooms (1997)', 'Legend of Lobo, The (1962)']
# Recommended items for user 1217: ['Unknown', 'Salut cousin! (1996)', 'Unknown']
# Recommended items for user 1218: ['Buddy Boy (1999)', 'Unknown', 'Unknown']
# Recommended items for user 1219: ['Tess of the Storm Country (1922)', "One Man's Hero (1999)", 'Number Seventeen (1932)']
# Recommended items for user 1220: ['Unknown', 'Number Seventeen (1932)', 'Unknown']
# Recommended items for user 1221: ['Quartier Mozart (1992)', 'Salut cousin! (1996)', "Lover's Knot (1996)"]
# Recommended items for user 1222: ['Prince of Central Park, The (1999)', 'Choices (1981)', 'Unknown']
# Recommended items for user 1223: ['Five Wives, Three Secretaries and Me (1998)', 'Unknown', 'Unknown']
# Recommended items for user 1224: ['Unknown', 'Buddy Boy (1999)', 'Lotto Land (1995)']
# Recommended items for user 1225: ['Unknown', 'Other Voices, Other Rooms (1997)', 'Dangerous Game (1993)']
# Recommended items for user 1226: ['Number Seventeen (1932)', 'Bird of Prey (1996)', 'Gendernauts (1999)']
# Recommended items for user 1227: ['Vermin (1998)', 'Broadway Damage (1997)', 'Hungarian Fairy Tale, A (1987)']
# Recommended items for user 1228: ['Gendernauts (1999)', 'Tess of the Storm Country (1922)', 'Phoenix (1998)']
# Recommended items for user 1229: ['Anguish (Angustia) (1986)', 'Fire on the Mountain (1996)', 'Desert Winds (1995)']
# Recommended items for user 1230: ['Mass Transit (1998)', 'Unknown', 'Kill, Baby... Kill! (Operazione Paura) (1966)']
# Recommended items for user 1231: ['Legend of Lobo, The (1962)', 'Third World Cop (1999)', 'Tess of the Storm Country (1922)']
# Recommended items for user 1232: ['Tess of the Storm Country (1922)', 'Legend of Lobo, The (1962)', 'Gendernauts (1999)']
# Recommended items for user 1233: ['Condo Painting (2000)', 'Legend of Lobo, The (1962)', 'Unknown']
# Recommended items for user 1234: ['Unknown', 'Legend of Lobo, The (1962)', 'Unknown']
# Recommended items for user 1235: ['Other Voices, Other Rooms (1997)', 'Proprietor, The (1996)', 'Easy Virtue (1927)']
# Recommended items for user 1236: ['Big Bang Theory, The (1994)', 'Jails, Hospitals & Hip-Hop (2000)', 'Penitentiary (1979)']
# Recommended items for user 1237: ['Train Ride to Hollywood (1978)', 'Black Tights (Les Collants Noirs) (1960)', 'An Unforgettable Summer (1994)']
# Recommended items for user 1238: ['Unknown', 'Anguish (Angustia) (1986)', 'Night Tide (1961)']
# Recommended items for user 1239: ['Night Tide (1961)', 'Hi-Yo Silver (1940)', 'Choices (1981)']
# Recommended items for user 1240: ['Eaten Alive (1976)', 'Storefront Hitchcock (1997)', 'Unknown']
# Recommended items for user 1241: ['Legend of Lobo, The (1962)', 'Harlem River Drive (1996)', 'Five Wives, Three Secretaries and Me (1998)']
# Recommended items for user 1242: ['Homage (1995)', 'Love Is All There Is (1996)', 'Unknown']
# Recommended items for user 1243: ['Tess of the Storm Country (1922)', 'Third World Cop (1999)', 'Love Walked In (1998)']
# Recommended items for user 1244: ['Prince of Central Park, The (1999)', 'Let it Come Down: The Life of Paul Bowles (1998)', 'Woman in Question, The (1950)']
# Recommended items for user 1245: ["Boricua's Bond (2000)", 'Unknown', 'Unknown']
# Recommended items for user 1246: ['Vermin (1998)', 'Unknown', 'Mouth to Mouth (Boca a boca) (1995)']
# Recommended items for user 1247: ['Eaten Alive (1976)', 'Unknown', 'Fire on the Mountain (1996)']
# Recommended items for user 1248: ['Und keiner weint mir nach (1996)', 'Unknown', 'Hungarian Fairy Tale, A (1987)']
# Recommended items for user 1249: ['Ill Gotten Gains (1997)', 'Ride (1998)', 'Tess of the Storm Country (1922)']
# Recommended items for user 1250: ['Number Seventeen (1932)', 'Unknown', 'Unknown']
# Recommended items for user 1251: ['Und keiner weint mir nach (1996)', 'Unknown', 'Black Tights (Les Collants Noirs) (1960)']
# Recommended items for user 1252: ['Unknown', 'Ratchet (1996)', 'Unknown']
# Recommended items for user 1253: ['Night Tide (1961)', 'Other Voices, Other Rooms (1997)', 'Love Walked In (1998)']
# Recommended items for user 1254: ['Desert Winds (1995)', 'Unknown', 'Unknown']
# Recommended items for user 1255: ['Phoenix (1998)', 'Run of the Country, The (1995)', 'It Happened Here (1961)']
# Recommended items for user 1256: ['Let it Come Down: The Life of Paul Bowles (1998)', 'Juno and Paycock (1930)', 'Unknown']
# Recommended items for user 1257: ['Unknown', 'Caught Up (1998)', 'Jails, Hospitals & Hip-Hop (2000)']
# Recommended items for user 1258: ['Unknown', 'Bluebeard (1944)', 'East Palace West Palace (Dong gong xi gong) (1997)']
# Recommended items for user 1259: ['Open Season (1996)', 'Unknown', 'Nô (1998)']
# Recommended items for user 1260: ['Unknown', 'Unknown', 'Unknown']
# Recommended items for user 1261: ['Unknown', 'Salut cousin! (1996)', 'Und keiner weint mir nach (1996)']
# Recommended items for user 1262: ['Hungarian Fairy Tale, A (1987)', 'Und keiner weint mir nach (1996)', 'Autumn Heart (1999)']
# Recommended items for user 1263: ['Prince of Central Park, The (1999)', 'Nô (1998)', 'Tess of the Storm Country (1922)']
# Recommended items for user 1264: ['Prince of Central Park, The (1999)', 'Open Season (1996)', 'Gendernauts (1999)']
# Recommended items for user 1265: ['Harvest (1998)', 'I Woke Up Early the Day I Died (1998)', 'Quartier Mozart (1992)']
# Recommended items for user 1266: ['Tess of the Storm Country (1922)', 'Boys, Les (1997)', 'Unknown']
# Recommended items for user 1267: ['Nô (1998)', 'Peanuts - Die Bank zahlt alles (1996)', 'Unknown']
# Recommended items for user 1268: ['Madagascar Skin (1995)', 'Dangerous Game (1993)', 'Beyond Bedlam (1993)']
# Recommended items for user 1269: ['Salut cousin! (1996)', 'Unknown', 'Unknown']
# Recommended items for user 1270: ['Und keiner weint mir nach (1996)', 'Number Seventeen (1932)', 'Song of Freedom (1936)']
# Recommended items for user 1271: ['Tess of the Storm Country (1922)', 'Anguish (Angustia) (1986)', 'Kill, Baby... Kill! (Operazione Paura) (1966)']
# Recommended items for user 1272: ['Tess of the Storm Country (1922)', 'Hungarian Fairy Tale, A (1987)', 'Night Tide (1961)']
# Recommended items for user 1273: ['Tess of the Storm Country (1922)', 'Nô (1998)', 'Five Wives, Three Secretaries and Me (1998)']
# Recommended items for user 1274: ['Photographer (Fotoamator) (1998)', 'Skipped Parts (2000)', 'Honigmond (1996)']
# Recommended items for user 1275: ['Und keiner weint mir nach (1996)', 'Tough and Deadly (1995)', 'Love in Bloom (1935)']
# Recommended items for user 1276: ['Salut cousin! (1996)', 'Let it Come Down: The Life of Paul Bowles (1998)', 'Somebody is Waiting (1996)']
# Recommended items for user 1277: ['Other Voices, Other Rooms (1997)', 'Unknown', 'Phoenix (1998)']
# Recommended items for user 1278: ["Lover's Knot (1996)", 'Unknown', 'Symphonie pastorale, La (1946)']
# Recommended items for user 1279: ['Unknown', 'Quartier Mozart (1992)', 'Garcu, Le (1995)']
# Recommended items for user 1280: ['Five Wives, Three Secretaries and Me (1998)', 'Unknown', 'Anguish (Angustia) (1986)']
# Recommended items for user 1281: ['Phoenix (1998)', 'Nô (1998)', 'Parallel Sons (1995)']
# Recommended items for user 1282: ['Tess of the Storm Country (1922)', 'Unknown', 'Unknown']
# Recommended items for user 1283: ['Black Tights (Les Collants Noirs) (1960)', 'Unknown', 'Unknown']
# Recommended items for user 1284: ['Unknown', 'Harvest (1998)', "I Don't Want to Talk About It (De eso no se habla) (1993)"]
# Recommended items for user 1285: ['Prince of Central Park, The (1999)', 'Naturally Native (1998)', 'Legend of Lobo, The (1962)']
# Recommended items for user 1286: ['Unknown', 'Unknown', 'Halfmoon (Paul Bowles - Halbmond) (1995)']
# Recommended items for user 1287: ['Salut cousin! (1996)', 'I Woke Up Early the Day I Died (1998)', 'Unknown']
# Recommended items for user 1288: ['Unknown', 'Unknown', 'Unknown']
# Recommended items for user 1289: ['Und keiner weint mir nach (1996)', 'Unknown', 'Beyond Bedlam (1993)']
# Recommended items for user 1290: ['Night Tide (1961)', "One Man's Hero (1999)", 'Unknown']
# Recommended items for user 1291: ['Mascara (1999)', 'Unknown', 'Outside Ozona (1998)']
# Recommended items for user 1292: ['Nô (1998)', 'Somebody is Waiting (1996)', 'Proprietor, The (1996)']
# Recommended items for user 1293: ['Ring, The (1927)', 'Kill, Baby... Kill! (Operazione Paura) (1966)', 'Ratchet (1996)']
# Recommended items for user 1294: ['Unknown', 'Somebody is Waiting (1996)', 'Cabinet of Dr. Ramirez, The (1991)']
# Recommended items for user 1295: ['Harvest (1998)', 'Nô (1998)', 'Sexual Life of the Belgians, The (1994)']
# Recommended items for user 1296: ['Legend of Lobo, The (1962)', 'Five Wives, Three Secretaries and Me (1998)', 'Tess of the Storm Country (1922)']
# Recommended items for user 1297: ['East Palace West Palace (Dong gong xi gong) (1997)', 'Kill, Baby... Kill! (Operazione Paura) (1966)', 'Crows and Sparrows (1949)']
# Recommended items for user 1298: ['Easy Virtue (1927)', 'Unknown', 'Detroit 9000 (1973)']
# Recommended items for user 1299: ['Prince of Central Park, The (1999)', 'Tess of the Storm Country (1922)', 'Legend of Lobo, The (1962)']
# Recommended items for user 1300: ['Loves of Carmen, The (1948)', 'Unknown', 'Unknown']
# Recommended items for user 1301: ["Lover's Knot (1996)", 'Mountain Eagle, The (1926)', 'Unknown']
# Recommended items for user 1302: ['Other Voices, Other Rooms (1997)', 'Nô (1998)', 'Proprietor, The (1996)']
# Recommended items for user 1303: ['Hungarian Fairy Tale, A (1987)', 'Unknown', 'Und keiner weint mir nach (1996)']
# Recommended items for user 1304: ['Buddy Boy (1999)', 'Torso (Corpi Presentano Tracce di Violenza Carnale) (1973)', 'Kill, Baby... Kill! (Operazione Paura) (1966)']
# Recommended items for user 1305: ["Boricua's Bond (2000)", 'Stranger, The (1994)', 'Unknown']
# Recommended items for user 1306: ['Live Virgin (1999)', 'Vermin (1998)', 'Legend of Lobo, The (1962)']
# Recommended items for user 1307: ['Vermin (1998)', 'Zone 39 (1997)', 'Unknown']
# Recommended items for user 1308: ['Unknown', 'Tess of the Storm Country (1922)', 'Ratchet (1996)']
# Recommended items for user 1309: ['Sadness of Sex, The (1995)', 'Squeeze (1996)', 'Letter From Death Row, A (1998)']
# Recommended items for user 1310: ['Master Ninja I (1984)', 'Unknown', 'Hippie Revolution, The (1996)']
# Recommended items for user 1311: ['Leopard Son, The (1996)', 'Unknown', 'Prince of Central Park, The (1999)']
# Recommended items for user 1312: ['Five Wives, Three Secretaries and Me (1998)', 'Gendernauts (1999)', 'Tess of the Storm Country (1922)']
# Recommended items for user 1313: ['Unknown', 'Unknown', "Wend Kuuni (God's Gift) (1982)"]
# Recommended items for user 1314: ['Open Season (1996)', 'Unknown', 'Under the Domin Tree (Etz Hadomim Tafus) (1994)']
# Recommended items for user 1315: ['Unknown', 'Eden (1997)', 'Crows and Sparrows (1949)']
# Recommended items for user 1316: ['Nô (1998)', 'Tess of the Storm Country (1922)', 'Legend of Lobo, The (1962)']
# Recommended items for user 1317: ['Madagascar Skin (1995)', 'Leopard Son, The (1996)', 'Beauty (1998)']
# Recommended items for user 1318: ['Hoogste tijd (1995)', 'Unknown', 'Buddy Boy (1999)']
# Recommended items for user 1319: ['Tess of the Storm Country (1922)', 'Sadness of Sex, The (1995)', 'Buddy Boy (1999)']
# Recommended items for user 1320: ['Prince of Central Park, The (1999)', 'Tess of the Storm Country (1922)', 'Unknown']
# Recommended items for user 1321: ['Number Seventeen (1932)', 'Children Are Watching us, The (Bambini ci guardano, I) (1942)', 'Nô (1998)']
# Recommended items for user 1322: ['Penitentiary (1979)', 'Slaves to the Underground (1997)', 'Unknown']
# Recommended items for user 1323: ['Zone 39 (1997)', 'Tess of the Storm Country (1922)', 'Big Bang Theory, The (1994)']
# Recommended items for user 1324: ['Salut cousin! (1996)', 'Unknown', 'Prince of Central Park, The (1999)']
# Recommended items for user 1325: ['Tess of the Storm Country (1922)', 'Third World Cop (1999)', 'Unknown']
# Recommended items for user 1326: ['Unknown', 'I Woke Up Early the Day I Died (1998)', 'Magic Hunter (1994)']
# Recommended items for user 1327: ['Marie Baie Des Anges (1997)', 'Proprietor, The (1996)', 'One Little Indian (1973)']
# Recommended items for user 1328: ['Quartier Mozart (1992)', 'Dangerous Game (1993)', 'Salut cousin! (1996)']
# Recommended items for user 1329: ['Children Are Watching us, The (Bambini ci guardano, I) (1942)', 'Proprietor, The (1996)', 'Skipped Parts (2000)']
# Recommended items for user 1330: ['Garcu, Le (1995)', 'Sadness of Sex, The (1995)', 'Letter From Death Row, A (1998)']
# Recommended items for user 1331: ['I Woke Up Early the Day I Died (1998)', 'Tess of the Storm Country (1922)', 'Prince of Central Park, The (1999)']
# Recommended items for user 1332: ['Tess of the Storm Country (1922)', 'Legend of Lobo, The (1962)', 'Nô (1998)']
# Recommended items for user 1333: ['Unknown', 'Unknown', 'Number Seventeen (1932)']
# Recommended items for user 1334: ['Ride (1998)', 'Black Tights (Les Collants Noirs) (1960)', 'Unknown']
# Recommended items for user 1335: ['Midnight Dancers (Sibak) (1994)', 'Unknown', 'Institute Benjamenta, or This Dream People Call Human Life (1995)']
# Recommended items for user 1336: ['Number Seventeen (1932)', 'Unknown', 'Unknown']
# Recommended items for user 1337: ['Inside (1996)', 'Anguish (Angustia) (1986)', 'Dream Man (1995)']
# Recommended items for user 1338: ['Tess of the Storm Country (1922)', 'Mass Transit (1998)', 'Unknown']
# Recommended items for user 1339: ['Uninvited Guest, An (2000)', 'Unknown', "One Man's Hero (1999)"]
# Recommended items for user 1340: ['War at Home, The (1996)', 'Unknown', 'Garcu, Le (1995)']
# Recommended items for user 1341: ['Other Voices, Other Rooms (1997)', 'Choices (1981)', 'Buddy Boy (1999)']
# Recommended items for user 1342: ['Loves of Carmen, The (1948)', 'Any Number Can Win (Mélodie en sous-sol ) (1963)', 'Unknown']
# Recommended items for user 1343: ['Dangerous Game (1993)', 'Ill Gotten Gains (1997)', 'Tess of the Storm Country (1922)']
# Recommended items for user 1344: ['Love Walked In (1998)', 'Dangerous Game (1993)', 'Other Voices, Other Rooms (1997)']
# Recommended items for user 1345: ['Harvest (1998)', 'Parallel Sons (1995)', 'Harlem River Drive (1996)']
# Recommended items for user 1346: ['Number Seventeen (1932)', 'Unknown', 'Unknown']
# Recommended items for user 1347: ['Unknown', 'Unforgotten: Twenty-Five Years After Willowbrook (1996)', 'Unknown']
# Recommended items for user 1348: ['Desert Winds (1995)', 'Choices (1981)', 'Unknown']
# Recommended items for user 1349: ['Tess of the Storm Country (1922)', 'Jeanne and the Perfect Guy (Jeanne et le garçon formidable) (1998)', 'Sexual Life of the Belgians, The (1994)']
# Recommended items for user 1350: ['Salut cousin! (1996)', "Associate, The (L'Associe)(1982)", 'Unknown']
# Recommended items for user 1351: ['Unknown', 'Law, The (Le Legge) (1958)', 'Century (1993)']
# Recommended items for user 1352: ['Unknown', 'Unknown', 'Kids of Survival (1993)']
# Recommended items for user 1353: ['Boys, Les (1997)', 'Frank and Ollie (1995)', "Boricua's Bond (2000)"]
# Recommended items for user 1354: ['Tess of the Storm Country (1922)', 'Unknown', 'Skin Game, The (1931)']
# Recommended items for user 1355: ['Salut cousin! (1996)', 'Unknown', 'Unknown']
# Recommended items for user 1356: ['Parallel Sons (1995)', 'Harvest (1998)', 'Hustler White (1996)']
# Recommended items for user 1357: ['Unknown', "Associate, The (L'Associe)(1982)", 'I Shot a Man in Vegas (1995)']
# Recommended items for user 1358: ['Prince of Central Park, The (1999)', 'Unknown', 'Salut cousin! (1996)']
# Recommended items for user 1359: ['Anguish (Angustia) (1986)', 'Champagne (1928)', 'East Palace West Palace (Dong gong xi gong) (1997)']
# Recommended items for user 1360: ['Unknown', 'Night Tide (1961)', 'Unknown']
# Recommended items for user 1361: ['Gendernauts (1999)', 'Tess of the Storm Country (1922)', 'Legend of Lobo, The (1962)']
# Recommended items for user 1362: ['Unknown', 'Unknown', 'Und keiner weint mir nach (1996)']
# Recommended items for user 1363: ['Salut cousin! (1996)', 'Nô (1998)', 'Unknown']
# Recommended items for user 1364: ['Salut cousin! (1996)', 'Unknown', 'Black Tights (Les Collants Noirs) (1960)']
# Recommended items for user 1365: ["Lover's Knot (1996)", 'Salut cousin! (1996)', 'Unknown']
# Recommended items for user 1366: ['Legend of Lobo, The (1962)', 'Five Wives, Three Secretaries and Me (1998)', 'Anguish (Angustia) (1986)']
# Recommended items for user 1367: ['Night Tide (1961)', 'Hungarian Fairy Tale, A (1987)', 'Open Season (1996)']
# Recommended items for user 1368: ['Gendernauts (1999)', 'Frisk (1995)', "One Man's Hero (1999)"]
# Recommended items for user 1369: ['Prince of Central Park, The (1999)', 'Unknown', 'Unknown']
# Recommended items for user 1370: ['Proprietor, The (1996)', 'Jails, Hospitals & Hip-Hop (2000)', 'Five Wives, Three Secretaries and Me (1998)']
# Recommended items for user 1371: ['Hillbillys in a Haunted House (1967)', 'Mouth to Mouth (Boca a boca) (1995)', 'Synthetic Pleasures (1995)']
# Recommended items for user 1372: ['Tess of the Storm Country (1922)', 'Anguish (Angustia) (1986)', 'Prince of Central Park, The (1999)']
# Recommended items for user 1373: ['Other Voices, Other Rooms (1997)', 'Lay of the Land, The (1997)', 'Ratchet (1996)']
# Recommended items for user 1374: ['Five Wives, Three Secretaries and Me (1998)', 'Unknown', 'Honigmond (1996)']
# Recommended items for user 1375: ['Unknown', 'Shadow of Angels (Schatten der Engel) (1976)', 'Legend of Lobo, The (1962)']
# Recommended items for user 1376: ['Let it Come Down: The Life of Paul Bowles (1998)', 'Night Tide (1961)', 'Unknown']
# Recommended items for user 1377: ['Hungarian Fairy Tale, A (1987)', 'Open Season (1996)', 'Fire on the Mountain (1996)']
# Recommended items for user 1378: ["I Don't Want to Talk About It (De eso no se habla) (1993)", 'Master Ninja I (1984)', 'Harvest (1998)']
# Recommended items for user 1379: ['Five Wives, Three Secretaries and Me (1998)', 'Unknown', 'Legend of Lobo, The (1962)']
# Recommended items for user 1380: ['Tess of the Storm Country (1922)', 'Desert Winds (1995)', 'Kill, Baby... Kill! (Operazione Paura) (1966)']
# Recommended items for user 1381: ['Crows and Sparrows (1949)', 'Night Tide (1961)', 'Identification of a Woman (Identificazione di una donna) (1982)']
# Recommended items for user 1382: ['Unknown', 'Unknown', 'Here Comes Cookie (1935)']
# Recommended items for user 1383: ['Bells, The (1926)', 'Sadness of Sex, The (1995)', 'Three Lives and Only One Death (1996)']
# Recommended items for user 1384: ['Proprietor, The (1996)', 'Homage (1995)', 'Nô (1998)']
# Recommended items for user 1385: ["Lover's Knot (1996)", 'Homage (1995)', "Mat' i syn (1997)"]
# Recommended items for user 1386: ['Anguish (Angustia) (1986)', 'Unknown', 'Unknown']
# Recommended items for user 1387: ['Und keiner weint mir nach (1996)', 'Fausto (1993)', 'Hoogste tijd (1995)']
# Recommended items for user 1388: ['Skipped Parts (2000)', 'Photographer (Fotoamator) (1998)', 'Unknown']
# Recommended items for user 1389: ['Tess of the Storm Country (1922)', 'Unknown', 'Unknown']
# Recommended items for user 1390: ['I Woke Up Early the Day I Died (1998)', 'Love in Bloom (1935)', 'Night Visitor, The (1970)']
# Recommended items for user 1391: ['Salut cousin! (1996)', 'Unknown', 'Unknown']
# Recommended items for user 1392: ['Quartier Mozart (1992)', 'Salut cousin! (1996)', 'Ratchet (1996)']
# Recommended items for user 1393: ['Love in Bloom (1935)', 'Unknown', 'Madagascar Skin (1995)']
# Recommended items for user 1394: ['I Woke Up Early the Day I Died (1998)', 'Magic Hunter (1994)', 'Unknown']
# Recommended items for user 1395: ['Easy Virtue (1927)', 'Pleasure Garden, The (1925)', 'Bye-Bye (1995)']
# Recommended items for user 1396: ['Unknown', 'Phoenix (1998)', 'Other Voices, Other Rooms (1997)']
# Recommended items for user 1397: ['Garcu, Le (1995)', 'Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) (1991)', 'Unknown']
# Recommended items for user 1398: ['Reach the Rock (1997)', "Lover's Knot (1996)", 'Men Cry Bullets (1997)']
# Recommended items for user 1399: ['Prince of Central Park, The (1999)', 'Tess of the Storm Country (1922)', 'Unknown']
# Recommended items for user 1400: ['Und keiner weint mir nach (1996)', 'They Bite (1996)', 'Other Voices, Other Rooms (1997)']
# Recommended items for user 1401: ['Unknown', 'Boys, Les (1997)', 'Quartier Mozart (1992)']
# Recommended items for user 1402: ['Tinseltown (1998)', 'Black Tights (Les Collants Noirs) (1960)', 'Crows and Sparrows (1949)']
# Recommended items for user 1403: ["Lover's Knot (1996)", 'Unknown', 'Quartier Mozart (1992)']
# Recommended items for user 1404: ['Tess of the Storm Country (1922)', 'Nô (1998)', 'Legend of Lobo, The (1962)']
# Recommended items for user 1405: ['Outside Ozona (1998)', 'Mascara (1999)', 'Unknown']
# Recommended items for user 1406: ['Night Tide (1961)', 'Legend of Lobo, The (1962)', 'Unknown']
# Recommended items for user 1407: ['Anguish (Angustia) (1986)', 'Nô (1998)', "Associate, The (L'Associe)(1982)"]
# Recommended items for user 1408: ['Prince of Central Park, The (1999)', 'Let it Come Down: The Life of Paul Bowles (1998)', 'Tess of the Storm Country (1922)']
# Recommended items for user 1409: ['Unknown', 'Eden (1997)', 'Unknown']
# Recommended items for user 1410: ['Legend of Lobo, The (1962)', 'Gendernauts (1999)', 'Tess of the Storm Country (1922)']
# Recommended items for user 1411: ['Five Wives, Three Secretaries and Me (1998)', 'Legend of Lobo, The (1962)', 'Anguish (Angustia) (1986)']
# Recommended items for user 1412: ['Tess of the Storm Country (1922)', 'Beyond Bedlam (1993)', 'Gendernauts (1999)']
# Recommended items for user 1413: ['Gendernauts (1999)', 'Unknown', 'Phoenix (1998)']
# Recommended items for user 1414: ['Ratchet (1996)', 'Juno and Paycock (1930)', 'Tess of the Storm Country (1922)']
# Recommended items for user 1415: ['Legend of Lobo, The (1962)', 'Salut cousin! (1996)', 'Unknown']
# Recommended items for user 1416: ['Chain of Fools (2000)', 'Nô (1998)', 'Unknown']
# Recommended items for user 1417: ['Number Seventeen (1932)', 'Unknown', 'Letter From Death Row, A (1998)']
# Recommended items for user 1418: ['Hungarian Fairy Tale, A (1987)', 'Let it Come Down: The Life of Paul Bowles (1998)', 'Unknown']
# Recommended items for user 1419: ['Legend of Lobo, The (1962)', 'Tess of the Storm Country (1922)', 'Desert Winds (1995)']
# Recommended items for user 1420: ['Nô (1998)', 'Harvest (1998)', 'Prince of Central Park, The (1999)']
# Recommended items for user 1421: ["I Don't Want to Talk About It (De eso no se habla) (1993)", 'Ratchet (1996)', 'Beyond Bedlam (1993)']
# Recommended items for user 1422: ['Tess of the Storm Country (1922)', 'Prince of Central Park, The (1999)', 'Anguish (Angustia) (1986)']
# Recommended items for user 1423: ['Silence of the Palace, The (Saimt el Qusur) (1994)', 'Tess of the Storm Country (1922)', 'Big Bang Theory, The (1994)']
# Recommended items for user 1424: ['Black Tights (Les Collants Noirs) (1960)', 'Unknown', 'Nô (1998)']
# Recommended items for user 1425: ['Unforgotten: Twenty-Five Years After Willowbrook (1996)', 'Spanish Fly (1998)', 'Ride (1998)']
# Recommended items for user 1426: ['Dream Man (1995)', 'Lay of the Land, The (1997)', 'Fire on the Mountain (1996)']
# Recommended items for user 1427: ["Lover's Knot (1996)", 'Unknown', 'Unknown']
# Recommended items for user 1428: ['Caught Up (1998)', "Lover's Knot (1996)", 'Unknown']
# Recommended items for user 1429: ['Number Seventeen (1932)', 'Unknown', 'Unknown']
# Recommended items for user 1430: ['Silence of the Palace, The (Saimt el Qusur) (1994)', 'Tess of the Storm Country (1922)', 'Eden (1997)']
# Recommended items for user 1431: ['Unknown', 'Third World Cop (1999)', 'Tough and Deadly (1995)']
# Recommended items for user 1432: ['Sadness of Sex, The (1995)', 'Ratchet (1996)', 'Unknown']
# Recommended items for user 1433: ['Slappy and the Stinkers (1998)', 'Somebody is Waiting (1996)', 'Number Seventeen (1932)']
# Recommended items for user 1434: ['Unknown', 'Legend of Lobo, The (1962)', 'Unknown']
# Recommended items for user 1435: ['Garcu, Le (1995)', 'Boys, Les (1997)', 'Hungarian Fairy Tale, A (1987)']
# Recommended items for user 1436: ['Tess of the Storm Country (1922)', 'Legend of Lobo, The (1962)', 'Skin Game, The (1931)']
# Recommended items for user 1437: ['Choices (1981)', 'Autumn Heart (1999)', 'Buddy Boy (1999)']
# Recommended items for user 1438: ['Unknown', 'Touki Bouki (Journey of the Hyena) (1973)', 'Squeeze (1996)']
# Recommended items for user 1439: ['Song of Freedom (1936)', 'Identification of a Woman (Identificazione di una donna) (1982)', 'Ménage (Tenue de soirée) (1986)']
# Recommended items for user 1440: ['Tess of the Storm Country (1922)', 'Let it Come Down: The Life of Paul Bowles (1998)', 'Nô (1998)']
# Recommended items for user 1441: ['Autumn Heart (1999)', 'Unknown', 'Magic Hunter (1994)']
# Recommended items for user 1442: ['Loves of Carmen, The (1948)', 'Unknown', 'Unknown']
# Recommended items for user 1443: ['Vermin (1998)', 'Not Love, Just Frenzy (Más que amor, frenesí) (1996)', 'Hoogste tijd (1995)']
# Recommended items for user 1444: ['Unknown', 'Number Seventeen (1932)', 'Unknown']
# Recommended items for user 1445: ['Unknown', "Lover's Knot (1996)", 'Naturally Native (1998)']
# Recommended items for user 1446: ['Tess of the Storm Country (1922)', 'Skin Game, The (1931)', 'Unknown']
# Recommended items for user 1447: ['Autumn Heart (1999)', 'Open Season (1996)', 'Unknown']
# Recommended items for user 1448: ["House of Exorcism, The (La Casa dell'esorcismo) (1974)", 'Proprietor, The (1996)', 'Anguish (Angustia) (1986)']
# Recommended items for user 1449: ['Project Moon Base (1953)', 'Legend of Lobo, The (1962)', 'Five Wives, Three Secretaries and Me (1998)']
# Recommended items for user 1450: ['Salut cousin! (1996)', 'Black Tights (Les Collants Noirs) (1960)', 'I Woke Up Early the Day I Died (1998)']
# Recommended items for user 1451: ['Let it Come Down: The Life of Paul Bowles (1998)', 'Prince of Central Park, The (1999)', 'Unknown']
# Recommended items for user 1452: ['Unknown', 'Anguish (Angustia) (1986)', 'Phoenix (1998)']
# Recommended items for user 1453: ['Crows and Sparrows (1949)', 'Black Tights (Les Collants Noirs) (1960)', 'Somebody is Waiting (1996)']
# Recommended items for user 1454: ['Unknown', 'Unknown', 'Mutters Courage (1995)']
# Recommended items for user 1455: ['Unknown', "Lover's Knot (1996)", 'Nô (1998)']
# Recommended items for user 1456: ['Prince of Central Park, The (1999)', 'Law, The (Le Legge) (1958)', 'Desert Winds (1995)']
# Recommended items for user 1457: ['Vermont Is For Lovers (1992)', 'Tess of the Storm Country (1922)', 'Kill, Baby... Kill! (Operazione Paura) (1966)']
# Recommended items for user 1458: ['Tess of the Storm Country (1922)', 'Third World Cop (1999)', 'Ring, The (1927)']
# Recommended items for user 1459: ['Unknown', 'Chain of Fools (2000)', 'Crows and Sparrows (1949)']
# Recommended items for user 1460: ['Black Tights (Les Collants Noirs) (1960)', 'Salut cousin! (1996)', 'Ride (1998)']
# Recommended items for user 1461: ['Vermin (1998)', 'Zone 39 (1997)', 'Hoogste tijd (1995)']
# Recommended items for user 1462: ['Legend of Lobo, The (1962)', 'Unknown', 'Unknown']
# Recommended items for user 1463: ['Tess of the Storm Country (1922)', 'Desert Winds (1995)', 'Zone 39 (1997)']
# Recommended items for user 1464: ['Open Season (1996)', 'Boy Called Hate, A (1995)', 'Quartier Mozart (1992)']
# Recommended items for user 1465: ["Associate, The (L'Associe)(1982)", 'Gendernauts (1999)', 'Unknown']
# Recommended items for user 1466: ['Proprietor, The (1996)', 'Prince of Central Park, The (1999)', 'Nô (1998)']
# Recommended items for user 1467: ['Five Wives, Three Secretaries and Me (1998)', 'Tess of the Storm Country (1922)', 'Legend of Lobo, The (1962)']
# Recommended items for user 1468: ['Prince of Central Park, The (1999)', 'Tess of the Storm Country (1922)', 'Ratchet (1996)']
# Recommended items for user 1469: ['Und keiner weint mir nach (1996)', 'Madagascar Skin (1995)', 'Night Tide (1961)']
# Recommended items for user 1470: ['Hi-Yo Silver (1940)', 'Ratchet (1996)', 'Leopard Son, The (1996)']
# Recommended items for user 1471: ['Und keiner weint mir nach (1996)', 'Proprietor, The (1996)', "One Man's Hero (1999)"]
# ...
# Recommended items for user 5899: ['Stranger, The (1994)', 'Kids of Survival (1993)', 'Touki Bouki (Journey of the Hyena) (1973)']
# Recommended items for user 5900: ['Legend of Lobo, The (1962)', 'Tess of the Storm Country (1922)', 'Unknown']
# Recommended items for user 5901: ['Unknown', 'Unknown', 'Legend of Lobo, The (1962)']
# Recommended items for user 5902: ['Let it Come Down: The Life of Paul Bowles (1998)', 'Harlem River Drive (1996)', 'Proprietor, The (1996)']
# Recommended items for user 5903: ['Five Wives, Three Secretaries and Me (1998)', 'Tess of the Storm Country (1922)', 'Legend of Lobo, The (1962)']
# Recommended items for user 5904: ['Number Seventeen (1932)', 'Unknown', 'Gendernauts (1999)']
# Recommended items for user 5905: ['Silence of the Palace, The (Saimt el Qusur) (1994)', 'Innocent Sleep, The (1995)', 'Love Walked In (1998)']
# Recommended items for user 5906: ['Tess of the Storm Country (1922)', 'Legend of Lobo, The (1962)', 'Gendernauts (1999)']
# Recommended items for user 5907: ['Unknown', 'Unknown', 'Unknown']
# Recommended items for user 5908: ['Unknown', 'Prince of Central Park, The (1999)', 'Unknown']
# Recommended items for user 5909: ['Prince of Central Park, The (1999)', 'Tess of the Storm Country (1922)', 'Unknown']
# Recommended items for user 5910: ['Prince of Central Park, The (1999)', 'Open Season (1996)', 'Run of the Country, The (1995)']
# Recommended items for user 5911: ['Hungarian Fairy Tale, A (1987)', 'Unknown', 'Unknown']
# Recommended items for user 5912: ['Harvest (1998)', 'Prince of Central Park, The (1999)', 'Choices (1981)']
# Recommended items for user 5913: ['Gendernauts (1999)', 'Tess of the Storm Country (1922)', 'Autumn Heart (1999)']
# Recommended items for user 5914: ['Prince of Central Park, The (1999)', 'Law, The (Le Legge) (1958)', 'Unknown']
# Recommended items for user 5915: ['Und keiner weint mir nach (1996)', 'Harvest (1998)', 'Hungarian Fairy Tale, A (1987)']
# Recommended items for user 5916: ['Unknown', 'Loves of Carmen, The (1948)', 'Hi-Yo Silver (1940)']
# Recommended items for user 5917: ['Legend of Lobo, The (1962)', 'Gendernauts (1999)', 'Tess of the Storm Country (1922)']
# Recommended items for user 5918: ['Unknown', 'Fire on the Mountain (1996)', 'Unknown']
# Recommended items for user 5919: ['Kill, Baby... Kill! (Operazione Paura) (1966)', 'Big Bang Theory, The (1994)', 'Unknown']
# Recommended items for user 5920: ['Prince of Central Park, The (1999)', 'Tess of the Storm Country (1922)', 'Legend of Lobo, The (1962)']
# Recommended items for user 5921: ['Tashunga (1995)', 'Unknown', 'Unknown']
# Recommended items for user 5922: ['Tess of the Storm Country (1922)', 'Unknown', 'Unknown']
# Recommended items for user 5923: ['Leopard Son, The (1996)', 'Tinseltown (1998)', 'Black Tights (Les Collants Noirs) (1960)']
# Recommended items for user 5924: ['Hungarian Fairy Tale, A (1987)', 'Tess of the Storm Country (1922)', 'Prince of Central Park, The (1999)']
# Recommended items for user 5925: ['Unknown', 'Salut cousin! (1996)', 'Quartier Mozart (1992)']
# Recommended items for user 5926: ['Tess of the Storm Country (1922)', 'Unknown', 'Anguish (Angustia) (1986)']
# Recommended items for user 5927: ['Legend of Lobo, The (1962)', 'Unknown', 'Unknown']
# Recommended items for user 5928: ['Unknown', 'Third World Cop (1999)', 'Guy (1996)']
# Recommended items for user 5929: ['Sadness of Sex, The (1995)', 'Train Ride to Hollywood (1978)', 'Ill Gotten Gains (1997)']
# Recommended items for user 5930: ['Ratchet (1996)', 'Tess of the Storm Country (1922)', 'One Little Indian (1973)']
# Recommended items for user 5931: ['Love in Bloom (1935)', 'Unknown', 'Unknown']
# Recommended items for user 5932: ['Unknown', 'Detroit 9000 (1973)', 'Unknown']
# Recommended items for user 5933: ['Unknown', 'Unknown', 'Black Tights (Les Collants Noirs) (1960)']
# Recommended items for user 5934: ['Legend of Lobo, The (1962)', 'Unknown', 'Mountain Eagle, The (1926)']
# Recommended items for user 5935: ['Hungarian Fairy Tale, A (1987)', 'Unknown', 'Let it Come Down: The Life of Paul Bowles (1998)']
# Recommended items for user 5936: ['Unknown', 'Unknown', 'Unknown']
# Recommended items for user 5937: ['Unknown', 'Caught Up (1998)', "Lover's Knot (1996)"]
# Recommended items for user 5938: ['Five Wives, Three Secretaries and Me (1998)', 'Unknown', 'Tess of the Storm Country (1922)']
# Recommended items for user 5939: ['Sadness of Sex, The (1995)', 'Crows and Sparrows (1949)', 'Beyond Bedlam (1993)']
# Recommended items for user 5940: ['Tess of the Storm Country (1922)', 'Prince of Central Park, The (1999)', 'Mass Transit (1998)']
# Recommended items for user 5941: ['Vermont Is For Lovers (1992)', 'Fire on the Mountain (1996)', 'Unknown']
# Recommended items for user 5942: ['Tess of the Storm Country (1922)', 'Nô (1998)', 'Unknown']
# Recommended items for user 5943: ['Napoleon and Samantha (1972)', 'Ring, The (1927)', 'Locusts, The (1997)']
# Recommended items for user 5944: ['Unknown', 'Photographer (Fotoamator) (1998)', 'Truce, The (1996)']
# Recommended items for user 5945: ['Unknown', 'Identification of a Woman (Identificazione di una donna) (1982)', 'Sexual Life of the Belgians, The (1994)']
# Recommended items for user 5946: ['Prince of Central Park, The (1999)', "House of Exorcism, The (La Casa dell'esorcismo) (1974)", 'Unknown']
# Recommended items for user 5947: ['Stranger, The (1994)', 'Unknown', 'Unknown']
# Recommended items for user 5948: ['Identification of a Woman (Identificazione di una donna) (1982)', 'Unknown', 'Crows and Sparrows (1949)']
# Recommended items for user 5949: ['Modulations (1998)', 'War Stories (1995)', 'Tough and Deadly (1995)']
# Recommended items for user 5950: ['Hoogste tijd (1995)', 'Spring Fever USA (a.k.a. Lauderdale) (1989)', 'Touki Bouki (Journey of the Hyena) (1973)']
# Recommended items for user 5951: ['Five Wives, Three Secretaries and Me (1998)', 'Tess of the Storm Country (1922)', 'Unknown']
# Recommended items for user 5952: ['Prince of Central Park, The (1999)', 'Tess of the Storm Country (1922)', 'Unknown']
# Recommended items for user 5953: ['Unknown', 'Caught Up (1998)', 'Lay of the Land, The (1997)']
# Recommended items for user 5954: ['Ill Gotten Gains (1997)', 'Sadness of Sex, The (1995)', 'Tess of the Storm Country (1922)']
# Recommended items for user 5955: ['Tess of the Storm Country (1922)', 'Hungarian Fairy Tale, A (1987)', 'Open Season (1996)']
# Recommended items for user 5956: ['Bird of Prey (1996)', 'Three Lives and Only One Death (1996)', 'Somebody is Waiting (1996)']
# Recommended items for user 5957: ['Open Season (1996)', 'Hungarian Fairy Tale, A (1987)', 'Unknown']
# Recommended items for user 5958: ['Tess of the Storm Country (1922)', 'Spanish Fly (1998)', 'Dream Man (1995)']
# Recommended items for user 5959: ['Harvest (1998)', 'Nô (1998)', 'Unknown']
# Recommended items for user 5960: ['Proprietor, The (1996)', 'Juno and Paycock (1930)', 'Let it Come Down: The Life of Paul Bowles (1998)']
# Recommended items for user 5961: ['Unknown', 'Phantom Love (Ai No Borei) (1978)', 'Unknown']
# Recommended items for user 5962: ['Mountain Eagle, The (1926)', 'Other Voices, Other Rooms (1997)', 'Next Step, The (1995)']
# Recommended items for user 5963: ['Unknown', "Lover's Knot (1996)", 'Unknown']
# Recommended items for user 5964: ['Waltzes from Vienna (1933)', 'Und keiner weint mir nach (1996)', 'Unknown']
# Recommended items for user 5965: ['Black Tights (Les Collants Noirs) (1960)', 'Let it Come Down: The Life of Paul Bowles (1998)', 'Und keiner weint mir nach (1996)']
# Recommended items for user 5966: ['Und keiner weint mir nach (1996)', 'Unknown', 'Phoenix (1998)']
# Recommended items for user 5967: ['Five Wives, Three Secretaries and Me (1998)', 'Spanish Fly (1998)', 'To Cross the Rubicon (1991)']
# Recommended items for user 5968: ['Innocent Sleep, The (1995)', 'Garcu, Le (1995)', 'Unknown']
# Recommended items for user 5969: ['Tess of the Storm Country (1922)', 'Boys, Les (1997)', 'Letter From Death Row, A (1998)']
# Recommended items for user 5970: ['Tess of the Storm Country (1922)', 'Legend of Lobo, The (1962)', 'Let it Come Down: The Life of Paul Bowles (1998)']
# Recommended items for user 5971: ['Tess of the Storm Country (1922)', 'Third World Cop (1999)', 'Legend of Lobo, The (1962)']
# Recommended items for user 5972: ['Unknown', 'Black Tights (Les Collants Noirs) (1960)', 'Homage (1995)']
# Recommended items for user 5973: ['Unknown', "Curtis's Charm (1995)", 'Waltzes from Vienna (1933)']
# Recommended items for user 5974: ['They Bite (1996)', 'Legend of Lobo, The (1962)', 'Madagascar Skin (1995)']
# Recommended items for user 5975: ["Curtis's Charm (1995)", 'Unknown', 'Woman in Question, The (1950)']
# Recommended items for user 5976: ['Tess of the Storm Country (1922)', 'Ratchet (1996)', 'Gendernauts (1999)']
# Recommended items for user 5977: ['Salut cousin! (1996)', 'Unknown', 'Lost Son, The (1999)']
# Recommended items for user 5978: ['Fire on the Mountain (1996)', 'Detroit 9000 (1973)', 'Horror Hotel (a.k.a. The City of the Dead) (1960)']
# Recommended items for user 5979: ['Happy Go Lovely (1951)', 'Unknown', 'Unknown']
# Recommended items for user 5980: ['Homage (1995)', 'Unknown', 'Vermont Is For Lovers (1992)']
# Recommended items for user 5981: ['Leopard Son, The (1996)', 'Hi-Yo Silver (1940)', 'Kids of Survival (1993)']
# Recommended items for user 5982: ['Let it Come Down: The Life of Paul Bowles (1998)', 'Unknown', 'Somebody is Waiting (1996)']
# Recommended items for user 5983: ['Unknown', 'Unknown', "Curtis's Charm (1995)"]
# Recommended items for user 5984: ['Silence of the Palace, The (Saimt el Qusur) (1994)', 'Unknown', 'Unknown']
# Recommended items for user 5985: ['Salut cousin! (1996)', 'Prince of Central Park, The (1999)', 'Hungarian Fairy Tale, A (1987)']
# Recommended items for user 5986: ['Tess of the Storm Country (1922)', 'Gendernauts (1999)', 'Legend of Lobo, The (1962)']
# Recommended items for user 5987: ['Und keiner weint mir nach (1996)', 'Unknown', 'Farmer & Chase (1995)']
# Recommended items for user 5988: ['Desert Winds (1995)', 'Santitos (1997)', 'Nô (1998)']
# Recommended items for user 5989: ['Unknown', 'Unknown', 'Hoogste tijd (1995)']
# Recommended items for user 5990: ['Unknown', 'Unknown', 'Number Seventeen (1932)']
# Recommended items for user 5991: ['Ratchet (1996)', 'Proprietor, The (1996)', 'Tess of the Storm Country (1922)']
# Recommended items for user 5992: ['Und keiner weint mir nach (1996)', 'Tough and Deadly (1995)', "I Don't Want to Talk About It (De eso no se habla) (1993)"]
# Recommended items for user 5993: ['It Happened Here (1961)', 'Anguish (Angustia) (1986)', 'Tess of the Storm Country (1922)']
# Recommended items for user 5994: ['Unknown', 'Day the Sun Turned Cold, The (Tianguo niezi) (1994)', 'Phoenix (1998)']
# Recommended items for user 5995: ['Tess of the Storm Country (1922)', 'Anguish (Angustia) (1986)', 'Desert Winds (1995)']
# Recommended items for user 5996: ['Tess of the Storm Country (1922)', 'Gendernauts (1999)', 'Dream Man (1995)']
# Recommended items for user 5997: ['Pleasure Garden, The (1925)', 'Tess of the Storm Country (1922)', "One Man's Hero (1999)"]
# Recommended items for user 5998: ['Men Cry Bullets (1997)', 'Magic Hunter (1994)', 'Beloved/Friend (Amigo/Amado) (1999)']
# Recommended items for user 5999: ['Tess of the Storm Country (1922)', 'Unknown', 'It Happened Here (1961)']
# Recommended items for user 6000: ['Tess of the Storm Country (1922)', 'Unknown', 'Unknown']
# Recommended items for user 6001: ['Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) (1991)', 'Unknown', 'Neon Bible, The (1995)']
# Recommended items for user 6002: ['Night Visitor, The (1970)', 'Farmer & Chase (1995)', 'Unknown']
# Recommended items for user 6003: ['Tess of the Storm Country (1922)', 'Unknown', 'Unknown']
# Recommended items for user 6004: ['Desert Winds (1995)', 'To Cross the Rubicon (1991)', 'Empty Mirror, The (1999)']
# Recommended items for user 6005: ['Tess of the Storm Country (1922)', 'Napoleon and Samantha (1972)', 'Unknown']
# Recommended items for user 6006: ['Unknown', 'Hi-Yo Silver (1940)', 'Boys, Les (1997)']
# Recommended items for user 6007: ['I Woke Up Early the Day I Died (1998)', 'Baby, The (1973)', 'Mondo (1996)']
# Recommended items for user 6008: ['Prince of Central Park, The (1999)', 'Night Tide (1961)', 'Tess of the Storm Country (1922)']
# Recommended items for user 6009: ['Night Tide (1961)', 'Hungarian Fairy Tale, A (1987)', 'Anguish (Angustia) (1986)']
# Recommended items for user 6010: ['Hungarian Fairy Tale, A (1987)', 'Let it Come Down: The Life of Paul Bowles (1998)', 'Und keiner weint mir nach (1996)']
# Recommended items for user 6011: ['Hungarian Fairy Tale, A (1987)', 'Salut cousin! (1996)', 'Prince of Central Park, The (1999)']
# Recommended items for user 6012: ['Five Wives, Three Secretaries and Me (1998)', 'Unknown', 'Homage (1995)']
# Recommended items for user 6013: ['Unknown', 'Hi-Yo Silver (1940)', 'Boys, Les (1997)']
# Recommended items for user 6014: ['Night Tide (1961)', 'Identification of a Woman (Identificazione di una donna) (1982)', 'Unknown']
# Recommended items for user 6015: ['Tess of the Storm Country (1922)', 'Salut cousin! (1996)', 'Unknown']
# Recommended items for user 6016: ['It Happened Here (1961)', 'Home Page (1999)', 'Unknown']
# Recommended items for user 6017: ['Prince of Central Park, The (1999)', 'Anguish (Angustia) (1986)', 'Unknown']
# Recommended items for user 6018: ['Tess of the Storm Country (1922)', 'Unknown', 'Unknown']
# Recommended items for user 6019: ['Unknown', 'Garcu, Le (1995)', 'Unknown']
# Recommended items for user 6020: ['Tess of the Storm Country (1922)', 'Unknown', 'It Happened Here (1961)']
# Recommended items for user 6021: ['Unknown', 'Somebody is Waiting (1996)', 'Anguish (Angustia) (1986)']
# Recommended items for user 6022: ['Unknown', 'Unknown', 'Silence of the Palace, The (Saimt el Qusur) (1994)']
# Recommended items for user 6023: ['Prince of Central Park, The (1999)', 'Tess of the Storm Country (1922)', 'Let it Come Down: The Life of Paul Bowles (1998)']
# Recommended items for user 6024: ['Unforgotten: Twenty-Five Years After Willowbrook (1996)', 'Ride (1998)', 'Und keiner weint mir nach (1996)']
# Recommended items for user 6025: ['Gendernauts (1999)', 'Legend of Lobo, The (1962)', 'Tess of the Storm Country (1922)']
# Recommended items for user 6026: ['Unknown', 'Unknown', 'Unknown']
# Recommended items for user 6027: ['Choices (1981)', 'Nô (1998)', 'Unknown']
# Recommended items for user 6028: ['Bye-Bye (1995)', 'Tinseltown (1998)', 'Love Is All There Is (1996)']
# Recommended items for user 6029: ['Five Wives, Three Secretaries and Me (1998)', 'Unknown', 'Anguish (Angustia) (1986)']
# Recommended items for user 6030: ['Unknown', 'Prerokbe Ognja (1995)', 'Unknown']
# Recommended items for user 6031: ['Skin Game, The (1931)', 'Tess of the Storm Country (1922)', 'Photographer (Fotoamator) (1998)']
# Recommended items for user 6032: ['Tess of the Storm Country (1922)', 'Vermont Is For Lovers (1992)', 'Kill, Baby... Kill! (Operazione Paura) (1966)']
# Recommended items for user 6033: ['Tess of the Storm Country (1922)', 'Prince of Central Park, The (1999)', 'Buddy Boy (1999)']
# Recommended items for user 6034: ['Prince of Central Park, The (1999)', 'Unknown', 'Photographer (Fotoamator) (1998)']
# Recommended items for user 6035: ['Unknown', 'Magic Hunter (1994)', 'I Woke Up Early the Day I Died (1998)']
# Recommended items for user 6036: ['Unknown', 'Unknown', 'Bloody Child, The (1996)']
# Recommended items for user 6037: ['Let it Come Down: The Life of Paul Bowles (1998)', 'Tess of the Storm Country (1922)', 'Legend of Lobo, The (1962)']
# Recommended items for user 6038: ['Unknown', 'Hi-Yo Silver (1940)', "Boricua's Bond (2000)"]
# Recommended items for user 6039: ['Unknown', 'Last Klezmer: Leopold Kozlowski, His Life and Music, The (1995)', 'Unknown']
# Recommended items for user 6040: ['My Best Girl (1927)', 'Proprietor, The (1996)', 'Eden (1997)']
